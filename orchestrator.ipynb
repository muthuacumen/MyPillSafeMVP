# %% [markdown]
# # PillSafe Orchestrator
# End-to-end ML pipeline: data → training → evaluation → artifact export

# %%
# Step 1 — Data collection
# %run data-collection/collect_pillbox.py --output data/raw/pillbox
print('[STUB] Step 1: Data collection — run collect_pillbox.py')

# %%
# Step 2 — Preprocessing
print('[STUB] Step 2: Preprocessing — resize, augment, split 80/10/10')

# %%
# Step 3 — Training (YOLOv8 segmentation)
# from ultralytics import YOLO
# model = YOLO('yolov8n-seg.pt')
# results = model.train(data='pillsafe.yaml', epochs=50, imgsz=640)
print('[STUB] Step 3: Training — uncomment YOLO lines after ultralytics install')

# %%
# Step 4 — Evaluation
# metrics = model.val()
# print(f'mAP@50: {metrics.box.map50:.3f}')
print('[STUB] Step 4: Evaluation')

# %%
# Step 5 — Export artifact
# model.export(format='onnx', path='training/trained-model-v0.onnx')
print('[STUB] Step 5: Export to training/trained-model-v0.h5')
